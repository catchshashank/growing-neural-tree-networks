# %%
# Run Experiment
tree = GrowingNeuralTree(max_depth=6)

logs = tree.fit(
    X_train, y_train, y_train_oh,
    X_val, y_val, y_val_oh,
    X_test, y_test, y_test_oh,
    root_epochs=10, root_bs=256, root_lr=1e-3,
    child_epochs=20, child_bs=128, child_lr=1e-4,
    stop_misclassified_threshold=0,
    stop_val_acc_threshold=None  # set to 0.99 for early stopping
)
