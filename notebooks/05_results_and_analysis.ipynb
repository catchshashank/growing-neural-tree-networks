# %%
# Plot accuracy/loss vs depth + misclassified
d = np.array(logs["depth"])

plt.figure(figsize=(14, 4))

plt.subplot(1, 3, 1)
plt.plot(d, logs["train_acc"], marker="o", label="Train")
plt.plot(d, logs["val_acc"], marker="o", label="Validation")
plt.plot(d, logs["test_acc"], marker="o", label="Test")
plt.xlabel("Tree Depth")
plt.ylabel("Accuracy")
plt.title("Accuracy as Tree Grows (Routing)")
plt.legend()

plt.subplot(1, 3, 2)
plt.plot(d, logs["train_loss"], marker="o", label="Train")
plt.plot(d, logs["val_loss"], marker="o", label="Validation")
plt.plot(d, logs["test_loss"], marker="o", label="Test")
plt.xlabel("Tree Depth")
plt.ylabel("Cross-Entropy Loss")
plt.title("Loss as Tree Grows (Routing)")
plt.legend()

plt.subplot(1, 3, 3)
plt.plot(d, logs["train_misclassified"], marker="o")
plt.xlabel("Tree Depth")
plt.ylabel("# Misclassified (Train)")
plt.title("Misclassified Samples vs Depth")

plt.tight_layout()
plt.show()
